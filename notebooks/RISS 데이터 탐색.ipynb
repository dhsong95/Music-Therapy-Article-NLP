# %% [markdown]
# ### RISS 데이터 탐색

# %% [markdown]
# * './data/articles_essential.csv'에 대한 개략적인 메타데이터 분석
# * 비어있는 데이터에 대한 수작업 구축 필요

# %%
# Step 1. 필요한 라이브러리 import
import pandas
import operator
import re

# %%
# Step 2. 데이터 개수 탐색
articles = pandas.read_csv('./data/articles_essential.csv', encoding='utf-8')
print('전체 데이터의 크기: {:d}\n'.format(len(articles)))

year_freq_dic = {}
for year in articles['year']:
    if year not in year_freq_dic.keys():
        year_freq_dic[year] = 1
    else:
        year_freq_dic[year] += 1

for y, f in sorted(year_freq_dic.items(), key=operator.itemgetter(0)):
    print('{:04d}년에 발표된 논문의 수 {:d}'.format(int(y), int(f)))
# Out:
# 전체 데이터의 크기: 239
#
# 1999년에 발표된 논문의 수 7
# 2000년에 발표된 논문의 수 5
# 2001년에 발표된 논문의 수 7
# 2002년에 발표된 논문의 수 7
# 2003년에 발표된 논문의 수 9
# 2004년에 발표된 논문의 수 10
# 2005년에 발표된 논문의 수 12
# 2006년에 발표된 논문의 수 10
# 2007년에 발표된 논문의 수 13
# 2008년에 발표된 논문의 수 9
# 2009년에 발표된 논문의 수 14
# 2010년에 발표된 논문의 수 14
# 2011년에 발표된 논문의 수 13
# 2012년에 발표된 논문의 수 14
# 2013년에 발표된 논문의 수 13
# 2014년에 발표된 논문의 수 10
# 2015년에 발표된 논문의 수 14
# 2016년에 발표된 논문의 수 16
# 2017년에 발표된 논문의 수 12
# 2018년에 발표된 논문의 수 16
# 2019년에 발표된 논문의 수 14

# %%
# Step 2. 비어 있는 데이터 확인
# 키워드가 없는 데이터 개수
cnt = 0
print('*******키워드가 없는 논문입니다. 수작업으로 추가가 필요합니다*******')
for keyword, year, vol, no, title in zip(articles['keyword'], articles['year'], articles['vol'], articles['no'], articles['title']):
    if keyword == 'MV':
        cnt += 1
        print('{:04d}-vol{:02d}-no{:02d}\t{:s}'.format(int(year), int(vol), int(no), title))
print('키워드가 없는 논문의 수는 총 {:d}입니다'.format(cnt))

print('\n')

# 초록이 없는 데이터 개수
cnt = 0
print('*******초록이 없는 논문입니다. 수작업으로 추가가 필요합니다*******')
for abstract, year, vol, no, title in zip(articles['abstract'], articles['year'], articles['vol'], articles['no'], articles['title']):
    if abstract == 'MV':
        cnt += 1
        print('{:04d}-vol{:02d}-no{:02d}\t{:s}'.format(int(year), int(vol), int(no), title))
print('초록이 없는 논문의 수는 총 {:d}입니다'.format(cnt))
# Out:
# *******키워드가 없는 논문입니다. 수작업으로 추가가 필요합니다*******
# 2019-vol21-no21	예술치료사 자기효능감 척도 개발 및 타당화 연구
# 2019-vol21-no21	델파이 방법을 통한 국내 재활음악치료 발전방안 연구
# 2019-vol21-no21	음악치료사의 훈련과정에서 경험한 열등감 인식과 통찰에 대한 자문화기술지
# 2019-vol21-no21	호스피스ㆍ완화의료 환자를 대상으로 한 국내ㆍ외 음악치료 연구 메타분석
# 2019-vol21-no21	수퍼바이지가 지각하는 음악치료 전문성과 수퍼비전 교육요구에 대한 합의적 질적연구
# 2018-vol20-no20	『한국음악치료학회지』투고규정 외
# 2016-vol18-no18	Development of an Assessment Tool for Measuring Social Interactions of Preschool Children with Autism Spectrum Disorders in an Individual Music Therapy Setting
# 2015-vol17-no17	음악활동에서 나타나는 유아의 사회성 평가도구 개발을 위한 예비연구
# 2015-vol17-no17	수퍼비젼관계가 예술치료 수퍼바이지의 전문성 발달에 미치는 영향: 자기신념의 매개와 수퍼비젼 만족도의 조절 효과
# 2015-vol17-no17	음악치료 프로그램이 치매노인에게 미치는 효과에 대한 메타분석
# 2015-vol17-no17	Effects of Educational Music Therapy on Knowledge of Triggers and Coping Skills, Motivation, and Treatment Eagerness in Patients on a Detoxification Unit: A Three-Group Cluster-Randomized Effectiveness Study
# 2015-vol17-no17	음악치료 슈퍼바이지가 지각하는 피드백 수용도, 슈퍼바이저 스타일, 슈퍼바이지 발달수준, 슈퍼비전 작업동맹 간의 구조분석
# 2015-vol17-no17	국내 음악치료 전문 학술 연구에서 사용된 측정도구의 동향 분석
# 2013-vol15-no15	심상음악치료(GIM)의 치료단계에 대한 주관성연구
# 2013-vol15-no15	음악활동에서 관찰될 수 있는 유아의 언어의사소통 평가도구 개발을 위한 예비연구
# 2012-vol14-no14	음악치료 및 다른 심리 교육적 치료 프로그램에 대한 일 병원 정신과 입원 환자들의 인식 조사
# 2012-vol14-no14	주력임상대상에 따른 음악치료 목적과 중재방법 비교 연구
# 2012-vol14-no14	음악치료 집단 수퍼비전에서 수퍼바이지가 지각하는 애착유형, 자기효능감, 정서적 유대, 수치심, 평가불안 간의 관계
# 2012-vol14-no14	음정의 차이가 개인의 음정 재생의 정확도에 미치는 영향
# 2012-vol14-no14	Immediate Effects of Music Therapy on Fatigue in Hospitalized Patients on a Bone Marrow Transplant Unit: A Pilot Study
# 2010-vol12-no12	즉흥연주 수업에서 음악치료 전공생이 지각하는 임상즉흥연주 경험에 관한 질적 연구
# 2010-vol12-no12	인터넷 중독 청소년의 개별 음악치료 사례연구
# 2007-vol09-no09	분열정동형 장애를 가진 성인과의 송라이팅을 통한 표현적·지지적 음악 심리치료
# 2007-vol09-no09	Book Review: 음악 심리치료의 역동성(Kenneth E. Bruscia 편저, 최병철, 김영신 공역)
# 2007-vol09-no09	Book Review 음악 심리치료의 역독성(Kenneth E. Bruscia 편저, 최병철, 김영신 공역)
# 2006-vol08-no08	산전 음악치료 프로그램이 초임부의 불안과 스트레스 감소에 미치는 영향
# 2006-vol08-no08	김영신 역(2006). 음악치료 접근법(Alice-Ann Darrow 편저). 학지사.
# 2003-vol05-no05	음악의 빠르기가 자율신경계 반응에 미치는 영향
# 2003-vol05-no05	음악활동이 노인의 시지각 기능에 미치는 영향
# 2003-vol05-no05	특수교사의 관점에서 본 관련서비스로서의 음악치료
# 2003-vol05-no05	청소년의 우울성향과 선호하는 음악 조성간의 관련성 연구
# 2003-vol05-no05	노래부르기가 초기치매 환자의 단어 회상에 미치는 효과
# 2003-vol05-no05	시설노인과 재가노인의 음악에 대한 정서적 반응 비교연구
# 2003-vol05-no05	시설노인과 재가노인의 음악에 대한 정서적 반응 비교연구
# 2003-vol05-no05	Healing Heritage: Paul Nordoff Exploring the Tonal Language of Music written by Stephanie Merritt
# 2003-vol05-no05	Mind. Music & Imagery: Unlocking the Treasures of Your Mind written by Clive Robbins & Carol Robbins
# 2002-vol04-no04	치료적 음악활동이 파킨슨 환자의 운동성과 정서에 미치는 효과
# 2002-vol04-no04	치료적 음악활동이 파키슨 환자의 운동성과 정서에 미치는 효과
# 2002-vol04-no04	음악요법/치료 효과에 대한 메타분석 연구
# 2002-vol04-no04	음악과 함께 한 심상경험이 만성통증환자의 심리적 지지에 미치는 영향
# 2002-vol04-no04	음악활동이 미혼모의 불안감소와 자아존중감 향상에 미치는 영향
# 2002-vol04-no04	신체표현을 사용한 음악감상이 만 5세 유아의 정서지능에 미치는 효과
# 2002-vol04-no04	음악활동이 통합된 발달지체유아의 사회적 상호작용 행동에 미치는 영향
# 2001-vol03-no03	음악활동이 자폐성 장애아동의 감각발달 및 사회 ·정서 영역에 미치는 효과
# 2001-vol03-no03	한국음악치료의 역사 - 1960년대부터 1996년까지 -
# 2001-vol03-no03	서브리미널 음악이 긴장이완에 미치는 영향
# 2001-vol03-no03	음악활동이 초등학교 아동의 우울성향 감소에 미치는 효과
# 2001-vol03-no03	노인의 음악선호도 조사 연구
# 2001-vol03-no03	음악이 개인의 심상 경험에 미치는 영향
# 2001-vol03-no03	음악적성 및 음악흥미와 정서지능과의 관련성 연구 - 중고생을 중심으로 -
# 2000-vol02-no02	음악적 자극이 자폐성 장애아동의 의사소통 반응에 미치는 효과
# 2000-vol02-no02	음악적 중재전략이 정신지체학생의 쌍연합 단어학습의 보유력에 미치는 효과
# 2000-vol02-no02	음악치료가 뇌졸증 환자의 폐기능 향상에 미치는 영향
# 2000-vol02-no02	음악치료가 뇌졸중 환자의 폐기능 향상에 미치는 영향
# 2000-vol02-no02	멜로디억양치료(Melodic Intonation Therapy)가 비유창성 실어증환자의 언어재활에 미치는 효과
# 1999-vol01-no01	음악치료에 대한 정신과 영역 전문인들의 인식도 조사
# 1999-vol01-no01	음악치료에 대한 정신과 영역 전문인들이 인식도 조사
# 1999-vol01-no01	"Journal of Music Therapy"(1987~1998)에 수록된 논문의 내용분석 연구
# 1999-vol01-no01	음악활동이 정신지체아동의 부적응행동 감소에 미치는 효과
# 1999-vol01-no01	음학활동이 정신지체아동의 부적응행동 감소에 미치는 효과
# 1999-vol01-no01	음악의 리듬이 뇌졸증 환자의 균형적 보행에 미치는 영향
# 1999-vol01-no01	음악의 리듬이 노졸증 환자의 균형적 보행에 미치는 영향
# 키워드가 없는 논문의 수는 총 62입니다
#
#
# *******초록이 없는 논문입니다. 수작업으로 추가가 필요합니다*******
# 2018-vol20-no20	『한국음악치료학회지』투고규정 외
# 2016-vol18-no18	Development of an Assessment Tool for Measuring Social Interactions of Preschool Children with Autism Spectrum Disorders in an Individual Music Therapy Setting
# 2015-vol17-no17	Effects of Educational Music Therapy on Knowledge of Triggers and Coping Skills, Motivation, and Treatment Eagerness in Patients on a Detoxification Unit: A Three-Group Cluster-Randomized Effectiveness Study
# 2015-vol17-no17	Effects of Educational Music Therapy on Knowledge of Triggers and Coping Skills, Motivation, and Treatment Eagerness in Patients on a Detoxification Unit : A Three-Group Cluster-Randomized Effectiveness Study
# 2014-vol16-no16	Effects of Mode and Rhythm on Working Memory as Measured by Sequential Digit Recall Performance
# 2013-vol15-no15	Effects of Educational Music Therapy on Knowledge of Social Supports in Acute Care Psychiatric Patients
# 2012-vol14-no14	Immediate Effects of Music Therapy on Fatigue in Hospitalized Patients on a Bone Marrow Transplant Unit: A Pilot Study
# 2012-vol14-no14	Immediate Effects of Music Therapy on Fatigue in Hospitalized Patients on a Bone Marrow Transplant Unit: A Pilot Study
# 2011-vol13-no13	Effects of Music Therapy on State Anxiety and Meaning in Life on Patients in an Acute Psychiatric Setting
# 2011-vol13-no13	The Effect of Live Music vs. Taped Music on Pain and Comfort in Palliative Care
# 2010-vol12-no12	즉흥연주 수업에서 음악치료 전공생이 지각하는 임상즉흥연주 경험에 관한 질적 연구
# 2007-vol09-no09	Book Review: 음악 심리치료의 역동성(Kenneth E. Bruscia 편저, 최병철, 김영신 공역)
# 2007-vol09-no09	Book Review 음악 심리치료의 역독성(Kenneth E. Bruscia 편저, 최병철, 김영신 공역)
# 2006-vol08-no08	김영신 역(2006). 음악치료 접근법(Alice-Ann Darrow 편저). 학지사.
# 2005-vol07-no07	창조적 음악치료 사례연구: Melissa
# 2005-vol07-no07	음악활동이 교류분석에 기초한 성인의 자아상태 변화에 미치는 영향
# 2005-vol07-no07	학부 음악전공 여부에 따른 음악치료대학원 교육과정에 대한 반응조사연구
# 2005-vol07-no07	음악 감상 중재와 리듬연주 중재가 직장인의 스트레스와 불안에 미치는 영향
# 2005-vol07-no07	정신지체 아동과 일반 아동의 운율 특성 비교
# 2005-vol07-no07	음악적 자극이 개인의 뇌파 변화에 미치는 영향
# 2005-vol07-no07	음악활동이 유아스트레스 감소에 미치는 영향
# 2005-vol07-no07	청소년의 감각추구 동기와 대중음악 선호와의 관련성 조사
# 2005-vol07-no07	사물놀이의 자진모리장단이 노인의 상지근육 활동도수에 미치는 영향
# 2005-vol07-no07	영아의 발달 과정에 따른 청각적 자극에 대한 음색 구별 반응 연구
# 2005-vol07-no07	학대받은 아동을 위한 음악치료 사례연구
# 2005-vol07-no07	국내 음악치료사의 직무만족도
# 2004-vol06-no06	음악의 선율유형과 음악적 훈련수준에 따른 선율인지 비교 연구
# 2004-vol06-no06	사이코드라마적인 음악치료가 부부의 의사소통 향상에 미치는 영향
# 2004-vol06-no06	동요활동이 자폐성 아동의 어휘습득에 미치는 효과
# 2004-vol06-no06	집단음악활동이 정신분열병 환자의 고독 및 대인관계에 미치는 영향
# 2004-vol06-no06	감상, 노래, 악기활동이 체열 대칭과 분포 양상에 미치는 영향
# 2004-vol06-no06	한국 노인의 가창 성역(歌唱聲域)에 관한 연구
# 2004-vol06-no06	음악감상이 치과치료시 경험하는 불안과 통증감소에 미치는 효과
# 2004-vol06-no06	음악이 기분 반응과 기분 일치성 기억회상에 미치는 영향
# 2004-vol06-no06	노래 부르기와 감상 시 아동이 선호하는 템포와 조성에 대한 연구
# 2004-vol06-no06	입원아동의 주사불안 감소를 위한 음악감상의 효과 연구
# 2003-vol05-no05	음악의 빠르기가 자율신경계 반응에 미치는 영향
# 2003-vol05-no05	음악활동이 노인의 시지각 기능에 미치는 영향
# 2003-vol05-no05	특수교사의 관점에서 본 관련서비스로서의 음악치료
# 2003-vol05-no05	청소년의 우울성향과 선호하는 음악 조성간의 관련성 연구
# 2003-vol05-no05	노래부르기가 초기치매 환자의 단어 회상에 미치는 효과
# 2003-vol05-no05	시설노인과 재가노인의 음악에 대한 정서적 반응 비교연구
# 2003-vol05-no05	Healing Heritage: Paul Nordoff Exploring the Tonal Language of Music written by Stephanie Merritt
# 2003-vol05-no05	Mind. Music & Imagery: Unlocking the Treasures of Your Mind written by Clive Robbins & Carol Robbins
# 2002-vol04-no04	치료적 음악활동이 파키슨 환자의 운동성과 정서에 미치는 효과
# 2002-vol04-no04	음악요법/치료 효과에 대한 메타분석 연구
# 2002-vol04-no04	음악과 함께 한 심상경험이 만성통증환자의 심리적 지지에 미치는 영향
# 2002-vol04-no04	음악활동이 미혼모의 불안감소와 자아존중감 향상에 미치는 영향
# 2002-vol04-no04	신체표현을 사용한 음악감상이 만 5세 유아의 정서지능에 미치는 효과
# 2002-vol04-no04	음악활동이 통합된 발달지체유아의 사회적 상호작용 행동에 미치는 영향
# 2001-vol03-no03	음악활동이 자폐성 장애아동의 감각발달 및 사회 ·정서 영역에 미치는 효과
# 2001-vol03-no03	한국음악치료의 역사 - 1960년대부터 1996년까지 -
# 2001-vol03-no03	서브리미널 음악이 긴장이완에 미치는 영향
# 2001-vol03-no03	음악활동이 초등학교 아동의 우울성향 감소에 미치는 효과
# 2001-vol03-no03	노인의 음악선호도 조사 연구
# 2001-vol03-no03	음악이 개인의 심상 경험에 미치는 영향
# 2001-vol03-no03	음악적성 및 음악흥미와 정서지능과의 관련성 연구 - 중고생을 중심으로 -
# 2000-vol02-no02	음악적 자극이 자폐성 장애아동의 의사소통 반응에 미치는 효과
# 2000-vol02-no02	음악적 중재전략이 정신지체학생의 쌍연합 단어학습의 보유력에 미치는 효과
# 2000-vol02-no02	음악치료가 뇌졸증 환자의 폐기능 향상에 미치는 영향
# 2000-vol02-no02	멜로디억양치료(Melodic Intonation Therapy)가 비유창성 실어증환자의 언어재활에 미치는 효과
# 1999-vol01-no01	음악치료에 대한 정신과 영역 전문인들의 인식도 조사
# 1999-vol01-no01	"Journal of Music Therapy"(1987~1998)에 수록된 논문의 내용분석 연구
# 1999-vol01-no01	음학활동이 정신지체아동의 부적응행동 감소에 미치는 효과
# 1999-vol01-no01	음악의 리듬이 뇌졸증 환자의 균형적 보행에 미치는 영향
# 초록이 없는 논문의 수는 총 65입니다

# %%
# Step 3. 영어 논문의 개수
print('다음은 제목이 영문인 논문 리스트입니다. 작성 언어 확인이 필요합니다')
kor = re.compile('[ㄱ-ㅎ|ㅏ-ㅣ|가-힣]')
cnt = 0
for year, vol, no, title in zip(articles['year'], articles['vol'], articles['no'], articles['title']):
    if not kor.search(title):
        cnt += 1
        print('{:04d}-vol{:02d}-no{:02d}\t{:s}'.format(int(year), int(vol), int(no), title))
print('영문 제목인 논문의 수는 총 {:d}입니다'.format(cnt))
# Out:
# 다음은 제목이 영문인 논문 리스트입니다. 작성 언어 확인이 필요합니다
# 2019-vol21-no21	A Twenty-year Historical Report: Music Therapy in Korea from 1996 to 2016
# 2019-vol21-no21	The Korean Journal of Music Therapy: Commemorating 20 years
# 2016-vol18-no18	Development of an Assessment Tool for Measuring Social Interactions of Preschool Children with Autism Spectrum Disorders in an Individual Music Therapy Setting
# 2016-vol18-no18	Development of an Assessment Tool for Measuring Social Interactions of Preschool Children with Autism Spectrum Disorders in an Individual Music Therapy Setting
# 2015-vol17-no17	Effects of Educational Music Therapy on Knowledge of Triggers and Coping Skills, Motivation, and Treatment Eagerness in Patients on a Detoxification Unit: A Three-Group Cluster-Randomized Effectiveness Study
# 2015-vol17-no17	Effects of Educational Music Therapy on Knowledge of Triggers and Coping Skills, Motivation, and Treatment Eagerness in Patients on a Detoxification Unit : A Three-Group Cluster-Randomized Effectiveness Study
# 2014-vol16-no16	Effects of Mode and Rhythm on Working Memory as Measured by Sequential Digit Recall Performance
# 2013-vol15-no15	Effects of Educational Music Therapy on Knowledge of Social Supports in Acute Care Psychiatric Patients
# 2012-vol14-no14	Immediate Effects of Music Therapy on Fatigue in Hospitalized Patients on a Bone Marrow Transplant Unit: A Pilot Study
# 2012-vol14-no14	Immediate Effects of Music Therapy on Fatigue in Hospitalized Patients on a Bone Marrow Transplant Unit: A Pilot Study
# 2011-vol13-no13	Effects of Music Therapy on State Anxiety and Meaning in Life on Patients in an Acute Psychiatric Setting
# 2011-vol13-no13	The Effect of Live Music vs. Taped Music on Pain and Comfort in Palliative Care
# 2010-vol12-no12	A Structural Analysis of Variables Influencing Music Therapy Outcomes
# 2003-vol05-no05	Healing Heritage: Paul Nordoff Exploring the Tonal Language of Music written by Stephanie Merritt
# 2003-vol05-no05	Mind. Music & Imagery: Unlocking the Treasures of Your Mind written by Clive Robbins & Carol Robbins
# 영문 제목인 논문의 수는 총 15입니다

# %%
# Step 4. 중복값 확인
print('제목이 중복된 논문을 확인합니다')
title_unique = []
cnt = 0
for year, vol, no, title in zip(articles['year'], articles['vol'], articles['no'], articles['title']):
    if title in title_unique:
        cnt += 1
        print('{:04d}-vol{:02d}-no{:02d}\t{:s}'.format(int(year), int(vol), int(no), title))
    else:
        title_unique.append(title)
print('제목이 중복된 논문의 수는 총 {:d}입니다'.format(cnt))
# Out:
# 제목이 중복된 논문을 확인합니다
# 2017-vol19-no19	타악기 연주활동이 재한 중국 유학생의 문화적응 스트레스 감소와 자아탄력성 증진에 미치는 효과
# 2016-vol18-no18	음악활동에서 관찰되는 유아 사회성 평가도구 개발을 위한 타당화 연구
# 2016-vol18-no18	Development of an Assessment Tool for Measuring Social Interactions of Preschool Children with Autism Spectrum Disorders in an Individual Music Therapy Setting
# 2015-vol17-no17	음악활동에서 나타나는 유아의 사회성 평가도구 개발을 위한 예비연구
# 2015-vol17-no17	음악치료 프로그램이 치매노인에게 미치는 효과에 대한 메타분석
# 2015-vol17-no17	음악치료 슈퍼바이지가 지각하는 피드백 수용도, 슈퍼바이저 스타일, 슈퍼바이지 발달수준, 슈퍼비전 작업동맹 간의 구조분석
# 2015-vol17-no17	국내 음악치료 전문 학술 연구에서 사용된 측정도구의 동향 분석
# 2013-vol15-no15	심상음악치료(GIM)의 치료단계에 대한 주관성연구
# 2013-vol15-no15	음악활동에서 관찰될 수 있는 유아의 언어의사소통 평가도구 개발을 위한 예비연구
# 2012-vol14-no14	음악치료 및 다른 심리 교육적 치료 프로그램에 대한 일 병원 정신과 입원 환자들의 인식 조사
# 2012-vol14-no14	주력임상대상에 따른 음악치료 목적과 중재방법 비교 연구
# 2012-vol14-no14	음악치료 집단 수퍼비전에서 수퍼바이지가 지각하는 애착유형, 자기효능감, 정서적 유대, 수치심, 평가불안 간의 관계
# 2012-vol14-no14	음정의 차이가 개인의 음정 재생의 정확도에 미치는 영향
# 2012-vol14-no14	Immediate Effects of Music Therapy on Fatigue in Hospitalized Patients on a Bone Marrow Transplant Unit: A Pilot Study
# 2010-vol12-no12	인터넷 중독 청소년의 개별 음악치료 사례연구
# 2010-vol12-no12	음악치료에 대한 일반인들의 인식도, 이해도 및 기대도 관련 조사연구
# 2006-vol08-no08	산전 음악치료 프로그램이 초임부의 불안과 스트레스 감소에 미치는 영향
# 2003-vol05-no05	시설노인과 재가노인의 음악에 대한 정서적 반응 비교연구
# 제목이 중복된 논문의 수는 총 18입니다

# %% [markdown]
# * 중복된 논문 제거 필요. 이때, 오타로 인해 중복된 논문으로 검출되지 않은 논문이 있으므로 주의
# * 키워드와 초록 수작업 추가
# * 영어 논문은 한글 텍스트 처리를 위해서 제거

# %%
# Step 2. 데이터 개수 탐색
articles = pandas.read_csv('./data/articles_essential_refined.csv', encoding='utf-8')
print('전체 데이터의 크기: {:d}\n'.format(len(articles)))

year_freq_dic = {}
for year in articles['year']:
    if year not in year_freq_dic.keys():
        year_freq_dic[year] = 1
    else:
        year_freq_dic[year] += 1

for y, f in sorted(year_freq_dic.items(), key=operator.itemgetter(0)):
    print('{:04d}년에 발표된 논문의 수 {:d}'.format(int(y), int(f)))
# Out:
# 전체 데이터의 크기: 216
#
# 1999년에 발표된 논문의 수 4
# 2000년에 발표된 논문의 수 5
# 2001년에 발표된 논문의 수 7
# 2002년에 발표된 논문의 수 7
# 2003년에 발표된 논문의 수 8
# 2004년에 발표된 논문의 수 10
# 2005년에 발표된 논문의 수 12
# 2006년에 발표된 논문의 수 9
# 2007년에 발표된 논문의 수 13
# 2008년에 발표된 논문의 수 9
# 2009년에 발표된 논문의 수 14
# 2010년에 발표된 논문의 수 12
# 2011년에 발표된 논문의 수 13
# 2012년에 발표된 논문의 수 9
# 2013년에 발표된 논문의 수 11
# 2014년에 발표된 논문의 수 10
# 2015년에 발표된 논문의 수 8
# 2016년에 발표된 논문의 수 14
# 2017년에 발표된 논문의 수 11
# 2018년에 발표된 논문의 수 16
# 2019년에 발표된 논문의 수 14
